# %% [markdown]
# <a href="https://colab.research.google.com/github/enidroman/Enid-Roman-Python-201-Project-2/blob/main/Enid_Roman_Python_201_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %% [markdown]
# ## **Diabetes/Diabetic Dataset**

# %% [markdown]
# I did an observation of how many rows and columns this particular dataset contains with dataframe.head. This dataset has 101766 rows and 50 columns.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')
df.head
# Out:
# <bound method NDFrame.head of         encounter_id  patient_nbr  ... diabetesMed readmitted
# 0            2278392      8222157  ...          No         NO
# 1             149190     55629189  ...         Yes        >30
# 2              64410     86047875  ...         Yes         NO
# 3             500364     82442376  ...         Yes         NO
# 4              16680     42519267  ...         Yes         NO
# ...              ...          ...  ...         ...        ...
# 101761     443847548    100162476  ...         Yes        >30
# 101762     443847782     74694222  ...         Yes         NO
# 101763     443854148     41088789  ...         Yes         NO
# 101764     443857166     31693671  ...         Yes         NO
# 101765     443867222    175429310  ...          No         NO
#
# [101766 rows x 50 columns]>

# %% [markdown]
# I then did a dataFrame.head() which return the first numbers rows and the last number of rows. It is useful for quickly testing if your object has the right type of data in it. I used (100) because I wanted to see the first 100 rows. I observed that some cleaning had to be done with the columns, some numbers were in scientific notation, some words needed space, some wording needed to be changed, some columns had to be deleted that was not needed, and question marks (?) that needed to be replaced.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')
df.head(100)
# Out:
#     encounter_id  patient_nbr             race  ... change diabetesMed readmitted
# 0        2278392      8222157        Caucasian  ...     No          No         NO
# 1         149190     55629189        Caucasian  ...     Ch         Yes        >30
# 2          64410     86047875  AfricanAmerican  ...     No         Yes         NO
# 3         500364     82442376        Caucasian  ...     Ch         Yes         NO
# 4          16680     42519267        Caucasian  ...     Ch         Yes         NO
# ..           ...          ...              ...  ...    ...         ...        ...
# 95       1195056     79549353        Caucasian  ...     No         Yes        >30
# 96       1195548    106343838        Caucasian  ...     No         Yes        >30
# 97       1212006     84981816        Caucasian  ...     Ch         Yes         NO
# 98       1257282     84488562            Other  ...     Ch         Yes         NO
# ...

# %% [markdown]
# I did a graph using the df.hist() function which just give me a measurment of each variables from the columns. I couldn't figure out how to make the charts not so close to each other so the titles could be more visible.

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8cd7daec50>,
# ...
#       dtype=object)

# %% [markdown]
# I observed the missing values "?" in the dataset. I then replaced the missing values with NaN to make it easier to replace all the missing value into a meaningful
# value. I did a df.head(100) to verify that all "?" were replace by NaN.

# %%
missing_values=["?"]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv',
                na_values=missing_values)
df.head(100)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     encounter_id  patient_nbr             race  ... change diabetesMed readmitted
# 0        2278392      8222157        Caucasian  ...     No          No         NO
# 1         149190     55629189        Caucasian  ...     Ch         Yes        >30
# 2          64410     86047875  AfricanAmerican  ...     No         Yes         NO
# 3         500364     82442376        Caucasian  ...     Ch         Yes         NO
# 4          16680     42519267        Caucasian  ...     Ch         Yes         NO
# ..           ...          ...              ...  ...    ...         ...        ...
# 95       1195056     79549353        Caucasian  ...     No         Yes        >30
# ...

# %% [markdown]
# I then replace missing values "NaN" with "Other" in column "race", "Unknown" in column "weight", and "Unknown" in column "medcial_specialty". I did a df.head(25) to verify the replacement occured.

# %%
missing_values =["NaN"]
replace = df['race'].replace()
df['race'].fillna("Other", inplace=True)
replace = df['weight'].replace()
df['weight'].fillna("Unknown", inplace=True)
replace = df['medical_specialty'].replace()
df['medical_specialty'].fillna("Unknown", inplace=True)


df.head(25)
# Out:
#     encounter_id  patient_nbr             race  ... change diabetesMed readmitted
# 0        2278392      8222157        Caucasian  ...     No          No         NO
# 1         149190     55629189        Caucasian  ...     Ch         Yes        >30
# 2          64410     86047875  AfricanAmerican  ...     No         Yes         NO
# 3         500364     82442376        Caucasian  ...     Ch         Yes         NO
# 4          16680     42519267        Caucasian  ...     Ch         Yes         NO
# 5          35754     82637451        Caucasian  ...     No         Yes        >30
# 6          55842     84259809        Caucasian  ...     Ch         Yes         NO
# 7          63768    114882984        Caucasian  ...     No         Yes        >30
# 8          12522     48330783        Caucasian  ...     Ch         Yes         NO
# 9          15738     63555939        Caucasian  ...     Ch         Yes         NO
# ...

# %% [markdown]
# I then use df.columns to observe the title of the columns from the dataset to see which columns I was able to use for my analysis and which once I will delete because I didn't need them.

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %% [markdown]
# I dropped 27 columns by using the drop_cols. I didn't think these columns were necessary for my analysis.

# %%
drop_cols=['admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'payer_code', 'num_procedures','number_outpatient', 'number_emergency', 'number_inpatient','max_glu_serum', 'A1Cresult','metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone','tolazamide', 'examide', 'citoglipton',]
df.drop(drop_cols, inplace = True, axis=1)
df.head()
# Out:
#    encounter_id  patient_nbr             race  ... change diabetesMed readmitted
# 0       2278392      8222157        Caucasian  ...     No          No         NO
# 1        149190     55629189        Caucasian  ...     Ch         Yes        >30
# 2         64410     86047875  AfricanAmerican  ...     No         Yes         NO
# 3        500364     82442376        Caucasian  ...     Ch         Yes         NO
# 4         16680     42519267        Caucasian  ...     Ch         Yes         NO
#
# [5 rows x 23 columns]

# %% [markdown]
# I then rename the columns with df.rename.

# %%
df.rename(columns={'encounter_id' : 'Encounter ID', 'patient_nbr' : 'Patient Number', 'race' : 'Race', 'gender' : 'Gender', 'age' : 'Age', 'weight' : 'Weight', 'time_in_hospital' : 'Number of Hospitalization', 
'medical_specialty' : 'Medical Specialty', 'num_lab_procedures': 'Number Lab Procedures', 'num_medications' : 'Number of Medications', 'diag_1' : 'Diagnosis 1', 'diag_2' : 'Diagnosis 2', 'diag_3' : 'Diagnosis 3', 
'number_diagnoses' : 'Number Diagnosis', 'insulin' : 'Insulin', 'glyburide-metformin': 'Glyburide-Metformin', 'glipizide-metformin' : 'Glipizide-Metformin', 'glimepiride-pioglitazone' : 'Gimepiride-Pioglitazone', 
'metformin-rosiglitazone' : 'Metformin-Rosiglitazone', 'metformin-pioglitazone' : 'Metformin-Pioglitazone', 'change' : 'Change', 'diabetesMed' : 'Diabetes Med.', 'readmitted' : 'Readmitted'}, inplace=True)
df
# Out:
#         Encounter ID  Patient Number  ... Diabetes Med. Readmitted
# 0            2278392         8222157  ...            No         NO
# 1             149190        55629189  ...           Yes        >30
# 2              64410        86047875  ...           Yes         NO
# 3             500364        82442376  ...           Yes         NO
# 4              16680        42519267  ...           Yes         NO
# ...              ...             ...  ...           ...        ...
# 101761     443847548       100162476  ...           Yes        >30
# 101762     443847782        74694222  ...           Yes         NO
# 101763     443854148        41088789  ...           Yes         NO
# 101764     443857166        31693671  ...           Yes         NO
# 101765     443867222       175429310  ...            No         NO
#
# [101766 rows x 23 columns]

# %% [markdown]
# I did a sns.pairplot graphing. It gives a comparison between each variable for an instant examination of the data. You can see in the Y and X axis has the same lined of variables.

# %%
sns.pairplot(df)

# %% [markdown]
# I did a sns.pairplot graphing by adding "Race" as a hue. It gives a comparison between each variable for each Race. You can see in the Y and X axis has the same lined of variables. The colors shows the different Race differntiated in different colors that is listed on the right side.

# %%
sns.pairplot(df,hue='Race')

# %% [markdown]
# I then use df.replace to seperate "AfricanAmerican" in "Race" column. I did a df.head(25) to verify the replacement occured.

# %%
df['Race'] = df['Race'].replace(['AfricanAmerican'], ['African American'])

df.head(25)
# Out:
#     Encounter ID  Patient Number  ... Diabetes Med. Readmitted
# 0        2278392         8222157  ...            No         NO
# 1         149190        55629189  ...           Yes        >30
# 2          64410        86047875  ...           Yes         NO
# 3         500364        82442376  ...           Yes         NO
# 4          16680        42519267  ...           Yes         NO
# 5          35754        82637451  ...           Yes        >30
# 6          55842        84259809  ...           Yes         NO
# 7          63768       114882984  ...           Yes        >30
# 8          12522        48330783  ...           Yes         NO
# 9          15738        63555939  ...           Yes         NO
# 10         28236        89869032  ...           Yes        >30
# 11         36900        77391171  ...           Yes        <30
# 12         40926        85504905  ...           Yes        <30
# 13         42570        77586282  ...           Yes         NO
# ...

# %% [markdown]
# I then use df.replace to "Unknown/Invalid" to  "Unknown" in "Race" column. I used df.head(25) see  that the replacement occured.

# %%
df['Gender'] = df['Gender'].replace(['Unknown/Invalid'], ['Unknown'])
df.head(25)
# Out:
#     Encounter ID  Patient Number  ... Diabetes Med. Readmitted
# 0        2278392         8222157  ...            No         NO
# 1         149190        55629189  ...           Yes        >30
# 2          64410        86047875  ...           Yes         NO
# 3         500364        82442376  ...           Yes         NO
# 4          16680        42519267  ...           Yes         NO
# 5          35754        82637451  ...           Yes        >30
# 6          55842        84259809  ...           Yes         NO
# 7          63768       114882984  ...           Yes        >30
# 8          12522        48330783  ...           Yes         NO
# 9          15738        63555939  ...           Yes         NO
# 10         28236        89869032  ...           Yes        >30
# 11         36900        77391171  ...           Yes        <30
# 12         40926        85504905  ...           Yes        <30
# 13         42570        77586282  ...           Yes         NO
# ...

# %% [markdown]
# I then use df.str.replace (r""([A-Z])", r" \1").str.strip() to add a space between the names of Medical Specialties in the column in " Medical Specialty". I use df.head(25) to see that the replacent had occured.

# %%
df['Medical Specialty'] = df['Medical Specialty'].str.replace( r"([A-Z])", r" \1").str.strip()

df.head(25)
# Out:
#     Encounter ID  Patient Number  ... Diabetes Med. Readmitted
# 0        2278392         8222157  ...            No         NO
# 1         149190        55629189  ...           Yes        >30
# 2          64410        86047875  ...           Yes         NO
# 3         500364        82442376  ...           Yes         NO
# 4          16680        42519267  ...           Yes         NO
# 5          35754        82637451  ...           Yes        >30
# 6          55842        84259809  ...           Yes         NO
# 7          63768       114882984  ...           Yes        >30
# 8          12522        48330783  ...           Yes         NO
# 9          15738        63555939  ...           Yes         NO
# 10         28236        89869032  ...           Yes        >30
# 11         36900        77391171  ...           Yes        <30
# 12         40926        85504905  ...           Yes        <30
# 13         42570        77586282  ...           Yes         NO
# ...

# %% [markdown]
# I then used df.round to change the numbers from scientific notation to replace it with integers. I used df.head(10) to see that the replacement had occured.

# %%
df['Encounter ID'].round()
df['Patient Number'].round()
df.head(10)
# Out:
#    Encounter ID  Patient Number  ... Diabetes Med. Readmitted
# 0       2278392         8222157  ...            No         NO
# 1        149190        55629189  ...           Yes        >30
# 2         64410        86047875  ...           Yes         NO
# 3        500364        82442376  ...           Yes         NO
# 4         16680        42519267  ...           Yes         NO
# 5         35754        82637451  ...           Yes        >30
# 6         55842        84259809  ...           Yes         NO
# 7         63768       114882984  ...           Yes        >30
# 8         12522        48330783  ...           Yes         NO
# 9         15738        63555939  ...           Yes         NO
#
# [10 rows x 23 columns]

# %% [markdown]
# I did a describe() function of this particular dataset to compute a summary of satistics pertaining to the DataFrame columns. This function gives the mean, std and IQR values. Again I notice the Year calculated into as an average. I don't understand why the Ecnounter ID and Patient Number is still in scientific notation when you can see that I had successfully change them to integers.

# %%
df.describe()
# Out:
#        Encounter ID  Patient Number  ...  Number of Medications  Number Diagnosis
# count  1.017660e+05    1.017660e+05  ...          101766.000000     101766.000000
# mean   1.652016e+08    5.433040e+07  ...              16.021844          7.422607
# std    1.026403e+08    3.869636e+07  ...               8.127566          1.933600
# min    1.252200e+04    1.350000e+02  ...               1.000000          1.000000
# 25%    8.496119e+07    2.341322e+07  ...              10.000000          6.000000
# 50%    1.523890e+08    4.550514e+07  ...              15.000000          8.000000
# 75%    2.302709e+08    8.754595e+07  ...              20.000000          9.000000
# max    4.438672e+08    1.895026e+08  ...              81.000000         16.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# I then did an analysis of "Race", "Gender", "Age", and "Number of Hospitalization". In the analysis female Caucasian ages 80 to 90 had more number of hospitalization.

# %%
df[['Race', 'Gender', 'Age', 'Number of Hospitalization']]
# Out:
#                     Race  Gender      Age  Number of Hospitalization
# 0              Caucasian  Female   [0-10)                          1
# 1              Caucasian  Female  [10-20)                          3
# 2       African American  Female  [20-30)                          2
# 3              Caucasian    Male  [30-40)                          2
# 4              Caucasian    Male  [40-50)                          1
# ...                  ...     ...      ...                        ...
# 101761  African American    Male  [70-80)                          3
# 101762  African American  Female  [80-90)                          5
# 101763         Caucasian    Male  [70-80)                          1
# 101764         Caucasian  Female  [80-90)                         10
# 101765         Caucasian    Male  [70-80)                          6
#
# [101766 rows x 4 columns]

# %% [markdown]
# I did a sns.boxplot showing a comparison with the "Number of Hospitlaization", "Age", and Gender. I observed Unknown Gender ages 70 to 80 had the most hospitalization.

# %%
sns.boxplot(x="Number of Hospitalization", y= "Age", hue="Gender", data = df)

# %% [markdown]
# I did a an analysis by a groupby function with the count of "Race", "Gender", and "Age". This gives the total number of diabetes by Race, Gender, and Age. In the analysis more Caucasian Female had diabetes.

# %%
df.groupby(['Race', 'Gender'])['Age'].count()
# Out:
# Race              Gender
# African American  Female     11728
#                   Male        7482
# Asian             Female       318
#                   Male         323
# Caucasian         Female     39689
#                   Male       36410
# Hispanic          Female      1092
#                   Male         945
# Other             Female      1881
#                   Male        1895
#                   Unknown        3
# Name: Age, dtype: int64

# %% [markdown]
# I did a bar plot graphing of the number of diabetics by Race, Gender, and Age. My observation was that there are more Caucasian female with diabietes.

# %%
df.groupby(['Race', 'Gender'])['Age'].count().plot(kind='bar')

# %% [markdown]
# I did an analysis by a groupby function with the count of "Race", Number of Diabetics by using the "Encounter ID" for the count. This gives the total number of diabetes by Race. In the analysis more Caucasian had diabetes then African American, Asian, Hispanic, and Other.

# %%
df.groupby(['Race'])['Encounter ID'].count()
# Out:
# Race
# African American    19210
# Asian                 641
# Caucasian           76099
# Hispanic             2037
# Other                3779
# Name: Encounter ID, dtype: int64

# %% [markdown]
# I did a bar plot graphing with the count of "Race" and Number of Diabetics by using the "Encounter ID" for the count. This gives the total number of diabetes by Race. I observed that more Caucasian had diabetes then African American, Asian, Hispanic, and Other.

# %%
df.groupby(['Race'])['Encounter ID'].count().plot(kind='bar')

# %% [markdown]
# I did an analysis by a groupby function with the count of "Gender", Number of Diabetics by using the "Encounter ID" for the count. This gives the total number of diabetes by Gender. In the analysis more Female had diabetes then Male and Unknown.

# %%
df.groupby(['Gender'])['Encounter ID'].count()
# Out:
# Gender
# Female     54708
# Male       47055
# Unknown        3
# Name: Encounter ID, dtype: int64

# %% [markdown]
# I did a bar plot graphing with the count of "Gender" and Number of Diabetics by using the "Encounter ID" for the count. This gives the total number of diabetes by Race. I observed that more Female had diabetes then Male and Unknown.

# %%
df.groupby(['Gender'])['Encounter ID'].count().plot(kind='bar')

# %% [markdown]
# I did an analysis by a groupby function with the count of "Age", Number of Diabetics by using the "Encounter ID" for the count. This gives the total number of diabetes by Age. In the analysis more people from ages 70 to 80 had diabetes then the other ages.

# %%
df.groupby(['Age'])['Encounter ID'].count()
# Out:
# Age
# [0-10)        161
# [10-20)       691
# [20-30)      1657
# [30-40)      3775
# [40-50)      9685
# [50-60)     17256
# [60-70)     22483
# [70-80)     26068
# [80-90)     17197
# [90-100)     2793
# Name: Encounter ID, dtype: int64

# %% [markdown]
# I did a bar plot graphing with the count of "Age" and Number of Diabetics by using the "Encounter ID" for the count. This gives the total number of diabetes by Age. I observed that more people from ages 70 to 80 had diabetes then the other ages

# %%
df.groupby(['Age'])['Encounter ID'].count().plot(kind='bar')

# %% [markdown]
# I did an analysis of the total number of diabetics by gender in African American. In the analysis there are more female of African American race with diabetes.

# %%
df[df['Race']=='African American'].groupby(['Gender'])['Encounter ID'].count()
# Out:
# Gender
# Female    11728
# Male       7482
# Name: Encounter ID, dtype: int64

# %% [markdown]
# I did a bar plot graphing of the total number of diabetics by gender in African American. I observed that there are more female of African American race with diabetes.

# %%
df[df['Race']=='African American'].groupby(['Gender'])['Encounter ID'].count().plot(kind='bar')

# %% [markdown]
# I did an analysis of the total number of diabetics by gender in Hispanic race. In the analysis there are more female of Hispanic race with diabetes.

# %%
df[df['Race']=='Hispanic'].groupby(['Gender'])['Encounter ID'].count()
# Out:
# Gender
# Female    1092
# Male       945
# Name: Encounter ID, dtype: int64

# %% [markdown]
# I did a bar plot graphing of the total number of diabetics by gender in Hispanic race. In the analysis there are more female of Hispanic race with diabetes.

# %%
df[df['Race']=='Hispanic'].groupby(['Gender'])['Encounter ID'].count().plot(kind='bar')

# %% [markdown]
# I did an analysis of the total number of diabetics by gender in Asian race. In the analysis there are more male of Asian race with diabetes.

# %%
df[df['Race']=='Asian'].groupby(['Gender'])['Encounter ID'].count()
# Out:
# Gender
# Female    318
# Male      323
# Name: Encounter ID, dtype: int64

# %% [markdown]
# I did a bar plot graphing of the total number of diabetics by gender in Asian race. In the analysis there are more male of Asian race with diabetes.

# %%
df[df['Race']=='Asian'].groupby(['Gender'])['Encounter ID'].count().plot(kind='bar')

# %% [markdown]
# I did an analysis of the total number of diabetics by gender in Other race. In the analysis there are more male of Other race with diabetes.

# %%
df[df['Race']=='Other'].groupby(['Gender'])['Encounter ID'].count()
# Out:
# Gender
# Female     1881
# Male       1895
# Unknown       3
# Name: Encounter ID, dtype: int64

# %% [markdown]
# I did a bar plot graphing of the total number of diabetics by gender in Other race. In the analysis there are more male of Other race with diabetes.

# %%
df[df['Race']=='Other'].groupby(['Gender'])['Encounter ID'].count().plot(kind='bar')

# %% [markdown]
# I did a an analysis to find how many by Race, Gender, and Age were taking Diabetic Medication. In the analysis there are more Caucasian Female ages 70 to 80 were taking diabetic medication.

# %%
df[['Race','Gender','Age','Diabetes Med.']].value_counts()
# Out:
# Race             Gender   Age       Diabetes Med.
# Caucasian        Female   [70-80)   Yes              8282
#                  Male     [70-80)   Yes              7797
#                           [60-70)   Yes              6942
#                  Female   [80-90)   Yes              6513
#                           [60-70)   Yes              6215
#                                                      ...
# Other            Unknown  [60-70)   No                  1
# Asian            Male     [20-30)   Yes                 1
#                           [0-10)    Yes                 1
#                  Female   [90-100)  No                  1
# AfricanAmerican  Female   [0-10)    No                  1
# Length: 191, dtype: int64

# %% [markdown]
# I did a bar plot graph to find how many by Race were taking Diabetic Medication. I observed that there are more Caucasian that were taking diabetic medication. I really wanted to do a bar graph with how many patient were taking Daibetic Medication by Race, Gender, and Age but I couldn't figure it out so I did the Bar Chart individually.

# %%
df[['Race','Diabetes Med.']].value_counts().plot(kind='bar')

# %% [markdown]
# I did a bar plot graph to find how many by Gender were taking Diabetic Medication. I observed that there are more Female were taking diabetic medication.

# %%
df[['Gender','Diabetes Med.']].value_counts().plot(kind='bar')

# %% [markdown]
# I did a bar plot graph to find how many by Age were taking Diabetic Medication. I observed that there are more Age 70 to 80 that were taking diabetic medication.

# %%
df[['Age','Diabetes Med.']].value_counts().plot(kind='bar')

# %% [markdown]
# I did an analysis of how many in total were taking diabetes medication. In the analysis 78363 were taking diabetic medication.

# %%
df['Diabetes Med.'].value_counts()
# Out:
# Yes    78363
# No     23403
# Name: Diabetes Med., dtype: int64

# %% [markdown]
# I did a bar plot graph of how many in total were taking diabetes medication. I observed that 78363 were taking diabetic medication.

# %%
df['Diabetes Med.'].value_counts().plot(kind='bar')

# %% [markdown]
# Comment from me. I had to do alot of data cleaning. I'm sure I could of removed more columns. There wasn't much numbers to work with like the New York City Regents Project. So I wasn't able to do much data satistics. I liked the first project much better. Maybe because I am number person.
